# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Data/data_for_predictions.csv')

# %%
data.head()
# Out:
#          Date         Open       Log  Log_Diff
# 0  2017-01-02   998.617004  6.906371  0.035635
# 1  2017-01-03  1021.599976  6.929125  0.022754
# 2  2017-01-04  1044.400024  6.951198  0.022073
# 3  2017-01-05  1156.729980  7.053352  0.102154
# 4  2017-01-06  1014.239990  6.921895 -0.131457

# %%
plt.rcParams.update({'figure.figsize': (20,20)})
plt.plot(data['Open'])

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace = True)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result_add = seasonal_decompose(data.Open, model='multiplicative', extrapolate_trend='freq')

#some data to research the correlation
trend = result_add.trend
seasonal = result_add.seasonal
residual = result_add.resid

plt.rcParams.update({'figure.figsize': (20,20)})
result_add.plot()
plt.show()

# %%
seasonal[:31]
# Out:
# Date
# 2017-01-02    0.997850
# 2017-01-03    1.001356
# 2017-01-04    1.000337
# 2017-01-05    1.001485
# 2017-01-06    0.999173
# 2017-01-07    0.999314
# 2017-01-08    1.000487
# 2017-01-09    0.997850
# 2017-01-10    1.001356
# 2017-01-11    1.000337
# 2017-01-12    1.001485
# 2017-01-13    0.999173
# 2017-01-14    0.999314
# 2017-01-15    1.000487
# 2017-01-16    0.997850
# 2017-01-17    1.001356
# 2017-01-18    1.000337
# 2017-01-19    1.001485
# 2017-01-20    0.999173
# 2017-01-21    0.999314
# 2017-01-22    1.000487
# 2017-01-23    0.997850
# 2017-01-24    1.001356
# 2017-01-25    1.000337
# 2017-01-26    1.001485
# 2017-01-27    0.999173
# 2017-01-28    0.999314
# 2017-01-29    1.000487
# 2017-01-30    0.997850
# 2017-01-31    1.001356
# 2017-02-01    1.000337
# Name: seasonal, dtype: float64
